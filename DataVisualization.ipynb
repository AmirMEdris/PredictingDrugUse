# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('prepeddata.csv',index_col='Unnamed: 0')
df['stim'] = df['stimulant'].apply(lambda x: 'low' if x <= 2 else 'high')
df
# Out:
#       Age  Education  Nscore  Escore  Oscore  Ascore  Cscore  Impulsive  \
# 1       3          1    39.0    36.0    42.0    37.0    42.0        4.0
# 2       2          4    29.0    52.0    55.0    48.0    41.0        3.0
# 3       3          1    31.0    45.0    40.0    32.0    34.0        2.0
# 4       1          3    34.0    34.0    46.0    47.0    46.0        2.0
# 5       3          4    43.0    28.0    43.0    41.0    50.0        4.0
# ...   ...        ...     ...     ...     ...     ...     ...        ...
# 1884    1          0    25.0    51.0    57.0    48.0    33.0        7.0
# 1885    1          0    33.0    51.0    50.0    48.0    30.0        7.0
# 1886    2          2    47.0    30.0    37.0    31.0    31.0        6.0
# 1887    1          0    45.0    26.0    48.0    32.0    22.0        8.0
# 1888    1          0    31.0    53.0    56.0    50.0    45.0        7.0
#
#       SensationSeeking  Alchol  Caff  Chocalate  Nicotine  stimulant  \
# ...

# %%
df.groupby('stim')[['Alchol','Nicotine','Chocalate','Caff']].mean().plot.bar()
plt.savefig('pics/LesserStimulantUsageByStimulant.png', bbox_inches='tight')

# %%
for i in ['Nscore','Escore','Oscore','Ascore','Cscore','Impulsive','SensationSeeking']:
    sns.lineplot(data=df.groupby(i)[['Alchol','Nicotine','Chocalate','Caff']].mean())
    plt.show()

# %%
for i in ['Alchol','Nicotine','Chocalate','Caff']:
    sns.lineplot(data=df.groupby(i)[["stimulant","depressant","hallucinagen"]].mean())
    plt.show(close=True)

# %%
for ii in ['Nscore','Escore','Oscore','Ascore','Cscore','Impulsive','SensationSeeking']:
    
    for i in ["stimulant","depressant","hallucinagen"]:
    
        sns.lineplot(df[ii],df[i])
        plt.legend(["stimulant","depressant","hallucinagen"])
       
        plt.ylabel('drug use likelihood')    
    plt.show()
# Out:
# C:\Users\Sigma\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Sigma\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
for i in ['Nscore','Escore','Oscore','Ascore','Cscore','Impulsive','SensationSeeking']:
    sns.scatterplot(df.groupby(i)[["stimulant","depressant","hallucinagen"]].mean().unstack([str(i)]))
# Out:
# C:\Users\Sigma\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Sigma\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
df.groupby('Impulsive')[['Nscore','Escore','Oscore','Ascore','Cscore']].mean().plot()















df.groupby('Impulsive')[['Nscore','Escore','Oscore','Ascore','Cscore']].mean().plot()








Out[29]:

<AxesSubplot:xlabel='Impulsive'>
# Out:
# <AxesSubplot:xlabel='Impulsive'>

# %%
df.groupby('stim')[['Nscore','Escore','Oscore','Ascore','Cscore']].mean().plot.bar()
plt.savefig('pics/PersonalityScoresByStimulant.png', bbox_inches='tight')

# %%
df.groupby('stim')[['Alchol','Caff','Chocalate','Nicotine']].mean().plot.bar()
plt.savefig('pics/SecondaryDrugUseAmongHighStimPatients.png', bbox_inches='tight')

# %%
sns.distplot(df.stimulant,label='Stimulant Use')
sns.distplot(df.hallucinagen,label = 'Hallucinagen Use')
sns.distplot(df.depressant,label = 'Depressant Use')


plt.legend()
# Out:
# C:\Users\Sigma\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sigma\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.distplot(df.Cscore,label = 'Careful')
# Out:
# C:\Users\Sigma\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Cscore', ylabel='Density'>

# %%
sns.distplot(df.Nscore,label='Nscore')
sns.distplot(df.Ascore,label = 'Ascore')
sns.distplot(df.Oscore,label = 'Oscore')

plt.legend()
# Out:
# C:\Users\Sigma\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sigma\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
df.groupby('stim')[['Impulsive','SensationSeeking']].mean().plot.bar()
plt.savefig('pics/ControlRelatedStatsByStimUse.png', bbox_inches='tight')

# %%
df.groupby('Nscore')[['depressant','stimulant','hallucinagen']].mean().plot()

plt.savefig('pics/DrugUseByHowAnxious.png', bbox_inches='tight')

# %%
df.groupby('Ascore')[['depressant','stimulant','hallucinagen']].mean().plot()
plt.savefig('pics/DrugUseByHowCooperativeYouAre.png', bbox_inches='tight')

# %%
df.groupby('Oscore')[['depressant','stimulant','hallucinagen']].mean().plot()
plt.savefig('pics/DrugUseByHowOpenToNewExperiencesYouAre.png', bbox_inches='tight')

# %%
df.groupby('Cscore')[['depressant','stimulant','hallucinagen']].mean().plot()
plt.savefig('pics/DrugUseByHowCarefulYouAre.png', bbox_inches='tight')

# %%
df.groupby('Escore')[['depressant','stimulant','hallucinagen']].mean().plot()
plt.savefig('pics/DrugUseByHowExtravertedYouAre.png', bbox_inches='tight')

# %%
sns.distplot(df.Impulsive)
sns.distplot(df.SensationSeeking)
plt.savefig('pics/ControlParams.png', bbox_inches='tight')
# Out:
# C:\Users\Sigma\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sigma\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.Nscore,label='Nscore')
sns.distplot(df.Ascore,label = 'Ascore')
sns.distplot(df.Oscore,label = 'Oscore')
sns.distplot(df.Cscore,label = 'Cscore')
sns.distplot(df.Escore,label = 'Escore')

plt.legend()
plt.savefig('pics/NormalDistPersonalityScoresParams.png', bbox_inches='tight')
# Out:
# C:\Users\Sigma\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sigma\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.distplot(df.stimulant,label='Stimulant Use')
sns.distplot(df.hallucinagen,label = 'Hallucinagen Use')
sns.distplot(df.depressant,label = 'Depressant Use')


plt.legend()
plt.savefig('pics/PoissonDistOfDrugUsers.png', bbox_inches='tight')
# Out:
# C:\Users\Sigma\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sigma\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
df.stimulant
# Out:
# 1       0.50
# 2       1.75
# 3       0.00
# 4       1.00
# 5       0.25
#         ...
# 1884    0.00
# 1885    0.00
# 1886    3.00
# 1887    0.00
# 1888    1.50
# Name: stimulant, Length: 1885, dtype: float64
