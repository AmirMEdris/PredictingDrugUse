# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('prepeddata.csv',index_col='Unnamed: 0')

# %%
df
# Out:
#       Age  Education  Nscore  Escore  Oscore  Ascore  Cscore  Impulsive  \
# 1       3          1    39.0    36.0    42.0    37.0    42.0        4.0
# 2       2          4    29.0    52.0    55.0    48.0    41.0        3.0
# 3       3          1    31.0    45.0    40.0    32.0    34.0        2.0
# 4       1          3    34.0    34.0    46.0    47.0    46.0        2.0
# 5       3          4    43.0    28.0    43.0    41.0    50.0        4.0
# ...   ...        ...     ...     ...     ...     ...     ...        ...
# 1884    1          0    25.0    51.0    57.0    48.0    33.0        7.0
# 1885    1          0    33.0    51.0    50.0    48.0    30.0        7.0
# 1886    2          2    47.0    30.0    37.0    31.0    31.0        6.0
# 1887    1          0    45.0    26.0    48.0    32.0    22.0        8.0
# 1888    1          0    31.0    53.0    56.0    50.0    45.0        7.0
#
#       SensationSeeking  Alchol  Caff  Chocalate  Nicotine  stimulant  \
# ...

# %%
df.groupby('Impulsive')[['Nscore','Escore','Oscore','Ascore','Cscore']].mean().plot()

# %%
sns.scatterplot(df.Escore,df.stimulant)

# %%
df.groupby('SensationSeeking')[['Nscore','Escore','Oscore','Ascore','Cscore']].mean().plot()

# %%
df.groupby('SensationSeeking')[['depressant','stimulant','hallucinagen']].mean().plot()

# %%
df.groupby('Impulsive')[['depressant','stimulant','hallucinagen']].mean().plot()

# %%
df.groupby('Impulsive')[['SensationSeeking','depressant','stimulant','hallucinagen']].mean().plot()

# %%
df.groupby('stimulant')[['Alchol','Caff','Chocalate','Nicotine']].mean().plot()

# %%
sns.distplot(df.stimulant,label='Stimulant Use')
sns.distplot(df.hallucinagen,label = 'Hallucinagen Use')
sns.distplot(df.depressant,label = 'Depressant Use')
plt.legend()

# %%
sns.lineplot(df.Impulsive ,df.stimulant)
sns.lineplot(df.SensationSeeking ,df.stimulant)
#class balance ,what do the personalities of people who are drug addicts look like

# %%
sns.distplot(df.Nscore,label='Nscore')
sns.distplot(df.Ascore,label = 'Ascore')
sns.distplot(df.Oscore,label = 'Oscore')

plt.legend()

# %%
df.groupby('Education')[['Impulsive','depressant','stimulant','hallucinagen']].mean().plot()

# %%
sns.pairplot(df,kind = 'jointplot')

# %%
df2 = df
# df2['stimulant'] = df['stimulant'].apply(lambda x: 'low' if x < 3 else 'high' )
df2 = df2[df2['stimulant'] == 'high'].drop('stimulant', axis =1)
ax = sns.barplot(x = 'stimulant' , y = ['Nscore','Escore','Oscore','Ascore','Cscore'], hue = 'high',data = df )
# ax = sns.barplot(data = df[['Nscore','Escore','Oscore','Ascore','Cscore']])
# sns.barplot(x = ['Nscore','Escore','Oscore','Ascore','Cscore'],y = df2.values[0]),sns.barplot(x = ['Nscore','Escore','Oscore','Ascore','Cscore'],y = df2.values[1])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-40d4e47b8448> in <module>
#       2 # df2['stimulant'] = df['stimulant'].apply(lambda x: 'low' if x < 3 else 'high' )
#       3 df2 = df2[df2['stimulant'] == 'high'].drop('stimulant', axis =1)
# ----> 4 ax = sns.barplot(x = 'stimulant' , y = ['Nscore','Escore','Oscore','Ascore','Cscore'], hue = 'high',data = df )
#       5 # ax = sns.barplot(data = df[['Nscore','Escore','Oscore','Ascore','Cscore']])
#       6 # sns.barplot(x = ['Nscore','Escore','Oscore','Ascore','Cscore'],y = df2.values[0]),sns.barplot(x = ['Nscore','Escore','Oscore','Ascore','Cscore'],y = df2.values[1])
#
# ...

# %%
df.groupby('stimulant')[['Impulsive','SensationSeeking']].mean().plot.bar()

# %%
df.groupby('Nscore')[['depressant','stimulant','hallucinagen']].mean().plot()

# %%
df.groupby('Ascore')[['depressant','stimulant','hallucinagen']].mean().plot()

# %%
df.groupby('Oscore')[['depressant','stimulant','hallucinagen']].mean().plot()

# %%
df.groupby('Cscore')[['depressant','stimulant','hallucinagen']].mean().plot()
